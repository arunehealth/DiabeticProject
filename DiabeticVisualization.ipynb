# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
glucose = pd.read_csv('cgm_date.csv')
steps = pd.read_csv('steps_date.csv')
sleep = pd.read_csv('beddit_date.csv')
gps = pd.read_csv('loc_date.csv')

# %%
df = pd.read_csv('final_df.csv')

# %%
df.head(2)
# Out:
#    Unnamed: 0   cgmdate  steps  sleep_duration time_spent          type  \
# 0           0  10182017  17511           25898       3:02     place 9.6
# 1           1  10182017  17511           25898       0:07  place unique
#
#    Historic_ Glucose
# 0              142.0
# 1              142.0

# %%
sns.pairplot(df, x_vars = ['cgmdate']  , y_vars = 'Historic_ Glucose',size = 7, aspect =0.7, kind= 'reg')

# %% [markdown]
# #It can be visualized in this pair plot that theere are numerous values for a single day, which means calculating  a mean of the glucose values can give a better picture of the predicted value.
# But the the data sets had very sparse data considering the same for other parameters and this resulted in loss of certain parameters. So all the individual data points were used for the visualization

# %%
sns.barplot(x = 'cgmdate', y = 'Historic_ Glucose', data = df)

# %%
sns.pairplot(df, y_vars = 'Historic_ Glucose', x_vars = ['steps'], size = 7, kind = 'reg')

# %%
sns.barplot(x = 'steps', y = 'Historic_ Glucose', data = df)

# %%
sns.pairplot(df, y_vars = 'Historic_ Glucose', x_vars = ['sleep_duration'], size = 7, kind = 'reg')

# %%
sns.barplot(x = 'sleep_duration', y = 'Historic_ Glucose', data = df)

# %% [markdown]
# "Sleep time" can be considered a better predictor of glucose levels compared to "step counts"

# %%
sns.pairplot(df, y_vars = 'Historic_ Glucose', x_vars = ['type'], size = 10)

# %%
sns.barplot(x = 'type', y = 'Historic_ Glucose', data = df)

# %%
sns.pairplot(df, y_vars = 'Historic_ Glucose', x_vars =[ 'steps'],size =7, kind = 'reg')

# %% [markdown]
# In this plot it can be seen that the glucose levels are not in direct relation to the number of steps taken by the user.
# This is in total contrast to the claims of the step counter that the device can be used as a method to control glucose in diabetics

# %%
sns.pairplot(df, x_vars = 'sleep_duration', y_vars = 'Historic_ Glucose',size =7,kind = 'reg')
